# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785736   Singapore        None              NaN              NaN
# 785737     Germany        None              NaN              NaN
# 785738    Malaysia        None              NaN              NaN
# 785739       Sudan        None              NaN              NaN
# 785740       India        None              NaN              NaN
#
#                               company_name  \
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 188526          Data Engineer
# 734961          Data Engineer
# 630058          Data Engineer
# 181221          Data Engineer
# 519366          Data Engineer
# 375523  Senior Data Scientist
# 773801          Data Engineer
# 458735      Software Engineer
# 705855   Senior Data Engineer
# 258084          Data Engineer
#
#                                                 job_title  \
# 188526  Azure Data Engineer - Data Factory/Synapse Ana...
# 734961                           Data Engineer Databricks
# 630058                              Dataops Lead Engineer
# 181221                                   Data Engineer OP
# 519366  Process Mining - Data Engineer & Implementatio...
# 375523                     Senior Clinical Data Scientist
# 773801                     Data Engineer (Hybrid) - 16861
# 458735                             Product Growth Analyst
# 705855                               Senior Data Engineer
# 258084                                      Data Engineer
#
#                                              job_location  \
# 188526                         Chennai, Tamil Nadu, India
# 734961  Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 630058               Jalisco del Refugio, Jalisco, Mexico
# 181221                           Bogotá, Bogota, Colombia
# 519366                                              India
# 375523                                   Redwood City, CA
# 773801                                     Fort Meade, MD
# 458735              Heredia Province, Heredia, Costa Rica
# 705855                                      Paris, France
# 258084                            Buenos Aires, Argentina
#
#                                               job_via job_schedule_type  \
# 188526                                   via LinkedIn         Full-time
# 734961                             via BeBee Malaysia         Full-time
# 630058                                      via BeBee         Full-time
# 181221                                via PostJobFree         Full-time
# 519366                                   via LinkedIn         Full-time
# 375523                                   via Snagajob         Full-time
# 773801                                   via LinkedIn         Full-time
# 458735  via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 705855                                      via BeBee         Full-time
# 258084  via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 188526               False                      India 2023-10-27 15:10:42
# 734961               False                   Malaysia 2023-02-04 22:04:58
# 630058               False                     Mexico 2023-10-08 12:37:32
# 181221               False                   Colombia 2023-08-27 15:26:39
# 519366               False                      India 2023-12-22 11:09:01
# 375523               False  California, United States 2023-06-25 18:25:12
# 773801               False       Texas, United States 2023-11-16 01:08:49
# 458735               False                 Costa Rica 2023-06-26 15:17:26
# 705855               False                     France 2023-05-13 04:05:34
# 258084               False                  Argentina 2023-09-14 07:22:34
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 188526                  False                 False          India
# 734961                   True                 False       Malaysia
# 630058                   True                 False         Mexico
# 181221                  False                 False       Colombia
# 519366                  False                 False          India
# 375523                  False                 False  United States
# 773801                  False                  True  United States
# 458735                  False                 False     Costa Rica
# 705855                   True                 False         France
# 258084                  False                 False      Argentina
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 188526        None              NaN              NaN
# 734961        None              NaN              NaN
# 630058        None              NaN              NaN
# 181221        None              NaN              NaN
# 519366        None              NaN              NaN
# 375523        None              NaN              NaN
# 773801        None              NaN              NaN
# 458735        None              NaN              NaN
# 705855        None              NaN              NaN
# 258084        None              NaN              NaN
#
#                                    company_name  \
# 188526                      Kiash Solutions LLP
# 734961   Agensi Pekerjaan Great Pyramid Sdn Bhd
# 630058                                  Workday
# 181221                                  Dev.Pro
# 519366                                      IBM
# 375523                                   Karius
# 773801  Mission Technologies, a division of HII
# 458735                               Databricks
# 705855                                    dcube
# 258084                                  Emprego
#
#                                                job_skills  \
# 188526  ['sql', 'python', 'azure', 'databricks', 'powe...
# 734961                     ['sql', 'databricks', 'spark']
# 630058  ['python', 'java', 'mysql', 'postgresql', 'azu...
# 181221  ['python', 'sql', 'mongodb', 'mongodb', 'gcp',...
# 519366  ['sql', 'python', 'r', 'matlab', 'oracle', 'ib...
# 375523     ['sql', 'python', 'r', 'sas', 'sas', 'oracle']
# 773801  ['python', 'java', 'nosql', 'elasticsearch', '...
# 458735  ['sql', 'python', 'r', 'databricks', 'aws', 's...
# 705855  ['sql', 'python', 'scala', 'nosql', 'azure', '...
# 258084  ['sql', 'nosql', 'mongo', 'python', 'java', 'c...
#
#                                           job_type_skills
# 188526  {'analyst_tools': ['power bi', 'tableau'], 'cl...
# 734961  {'cloud': ['databricks'], 'libraries': ['spark...
# 630058  {'analyst_tools': ['qlik', 'splunk'], 'cloud':...
# 181221  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 519366  {'analyst_tools': ['sap'], 'cloud': ['oracle',...
# 375523  {'analyst_tools': ['sas'], 'cloud': ['oracle']...
# 773801  {'analyst_tools': ['excel'], 'cloud': ['aws'],...
# 458735  {'analyst_tools': ['excel', 'sheets', 'tableau...
# 705855  {'cloud': ['azure', 'databricks', 'snowflake']...
# 258084  {'analyst_tools': ['ssis', 'power bi'], 'cloud...

# %%
dataset=load_dataset('lukebarousse/data_jobs')
dforiginal=dataset['train'].to_pandas()

# %%
dfcopy=dforiginal

# %%
id(dforiginal)
# Out:
# 1497885588240

# %%
id(dfcopy)
# Out:
# 1497885588240

# %%
dfcopy=dforiginal.copy()

# %%
id(dfcopy)
# Out:
# 1497885588560

# %%
id(dforiginal)
# Out:
# 1497885588240
