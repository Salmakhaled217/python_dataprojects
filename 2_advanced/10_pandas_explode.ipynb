# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import ast
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda skill: ast.literal_eval(skill)if pd.notna(skill)else skill)

# %%
df_expoled=df.explode('job_skills').copy()

# %%
df_expoled
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_expoled['job_skills'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
skill_count=df_expoled.groupby(by=['job_title_short','job_skills']).size()
skill_count
# Out:
# job_title_short    job_skills
# Business Analyst   airflow        318
#                    airtable        17
#                    alteryx       1078
#                    angular         87
#                    ansible        120
#                                  ...
# Software Engineer  wrike            4
#                    wsl             13
#                    xamarin         35
#                    yarn           145
#                    zoom           229
# Length: 2256, dtype: int64

# %%
type(skill_count)
# Out:
# pandas.core.series.Series

# %%
df_skill_count=skill_count.reset_index(name='count')
df_skill_count=df_skill_count.sort_values('count',ascending=False)
df_skill_count
# Out:
#             job_title_short   job_skills   count
# 1066         Data Scientist       python  113711
# 865           Data Engineer          sql  113130
# 830           Data Engineer       python  108022
# 625            Data Analyst          sql   92428
# 1101         Data Scientist          sql   78982
# ...                     ...          ...     ...
# 266          Cloud Engineer       delphi       1
# 1920  Senior Data Scientist  objective-c       1
# 1400    Senior Data Analyst      couchdb       1
# 298          Cloud Engineer      haskell       1
# 631            Data Analyst         suse       1
#
# [2256 rows x 3 columns]

# %%
job_title='Data Analyst'
s_count=10
df_final=df_skill_count[df_skill_count['job_title_short']==job_title].head(s_count)
df_final.plot(kind='barh',x='job_skills',y='count')
plt.ylabel('')
plt.xlabel('count ')
plt.title(f'count of top {s_count} skills for{job_title}')
plt.gca().invert_yaxis()
plt.show()
